# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_regression

df = pd.read_csv('placement.csv')
#X,y = make_regression(n_samples=100,n_features=1,noise=10)

# %%
plt.figure(figsize=(10,7))
plt.scatter(x=df['cgpa'], y=df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package in LPA')
plt.title('Placement Files')
plt.show()

# %%
X = np.array(df['cgpa']).reshape(-1,1)
y = np.array(df['package']).reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.svm import SVR, LinearSVR
model = SVR()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:1107: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.metrics import r2_score,mean_absolute_percentage_error,mean_absolute_error

print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test, y_pred))
# Out:
# 0.3068064847383955
# 0.69248451807341

# %%
plt.figure(figsize=(10,7))
plt.scatter(x=df['cgpa'], y=df['package'])
plt.plot(X_test, model.predict(X_test), color='red')
plt.xlabel('CGPA')
plt.ylabel('Package in LPA')
plt.title('Placement Files')
plt.show()
