# %% [markdown]
# # Gaussian Naive Bayes - Explained

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/pima-indians-diabetes-database/diabetes.csv

# %%
# Gaussian Naive Bayes Classification
import numpy as np
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split,GridSearchCV
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
import warnings
warnings.filterwarnings("ignore")
import scipy.stats as stats

# %matplotlib inline
data = pd.read_csv('/kaggle/input/pima-indians-diabetes-database/diabetes.csv')

X = data.drop(columns=['Outcome'],axis=1)
Y = data['Outcome']

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.isin([0]).sum()
# Out:
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %% [markdown]
# ## EDA

# %%
def univariateAnalysis_numeric1(column,nbins):
    print("\nDescription of " + column)
    print("----------------------------------------------------------------------------")
    print(data[column].describe(),end=' ')

    print("\nCentral values of " + column)
    print("----------------------------------------------------------------------------")
    #Central values 
    print('\nMinimum : ', data[column].min(),end=' ')
    print('\nMaximum : ', data[column].max(),end=' ')
    print('\nMean value : ', data[column].mean(),end=' ')
    print('\nMedian value : ', data[column].median(),end=' ')
    print('\nStandard deviation : ', data[column].std(),end=' ')
    print('\nNull values : ', data[column].isnull().any(),end=' ')
    print('\nNull values : ', data[column].isnull().sum().sum(),end=' ')

    print("\nQuartile of " + column)
    print("----------------------------------------------------------------------------")
    #Quartiles
    Q1=data[column].quantile(q=0.25)
    Q3=data[column].quantile(q=0.75)
    print('1st Quartile (Q1) is: ', Q1)
    print('3st Quartile (Q3) is: ', Q3)
    print('Interquartile range (IQR) is ', stats.iqr(data[column]))

    print("\nOutlier detection from Interquartile range (IQR) " + column)
    print("----------------------------------------------------------------------------")
    L_outliers=Q1-1.5*(Q3-Q1)
    U_outliers=Q3+1.5*(Q3-Q1)
    print('\nLower outliers range: ', L_outliers)
    print('\nUpper outliers range: ', U_outliers)
    print('Number of outliers in upper : ', data[data[column]>U_outliers][column].count())
    print('Number of outliers in lower : ', data[data[column]<L_outliers][column].count())
    print('% of Outlier in upper: ',round(data[data[column]>U_outliers][column].count()*100/len(data)), '%')
    print('% of Outlier in lower: ',round(data[data[column]<L_outliers][column].count()*100/len(data)), '%')

    #boxplot
    plt.figure()
    print("\nBoxPlot of " + column)
    print("----------------------------------------------------------------------------")
    ax = sns.boxplot(x=data[column])
    plt.show()
    
    #distplot
    plt.figure()
    print("\ndistplot of " + column)
    print("----------------------------------------------------------------------------")
    sns.distplot(data[column])
    plt.show()
    
    #histogram
    plt.figure()
    print("\nHistogram of " + column)
    print("----------------------------------------------------------------------------")
    sns.distplot(data[column], kde=False, color='red')
    plt.show()

    # Plotting mean, median and mode
    plt.figure()
    print("\nHistogram with mean, median and mode of " + column)
    print("----------------------------------------------------------------------------")
    mean=data[column].mean()
    median=data[column].median()
    mode=data[column].mode()

    print('Mean: ',mean,'\nMedian: ',median,'\nMode: ',mode[0])
    plt.hist(data[column],bins=100,color='lightblue') #Plot the histogram
    plt.axvline(mean,color='green',label='Mean')     # Draw lines on the plot for mean median and the two modes we have in GRE Score
    plt.axvline(median,color='blue',label='Median')
    plt.axvline(mode[0],color='red',label='Mode1')
    plt.legend()              # Plot the legend
    plt.show()

    print("\nSkewness of " + column)
    print("----------------------------------------------------------------------------")

    print(data[column].skew())
    
    fig, (ax1)=plt.subplots(1,0,figsize=(13,5))

# %%
df_num = data.select_dtypes(include = ['float64', 'int64'])
lstnumericcolumns = list(df_num.columns.values)
len(lstnumericcolumns)
# Out:
# 9

# %%
for x in lstnumericcolumns:
    univariateAnalysis_numeric1(x,20)
# Out:
# Description of Pregnancies
# ----------------------------------------------------------------------------
# count    768.000000
# mean       3.845052
# std        3.369578
# min        0.000000
# 25%        1.000000
# 50%        3.000000
# 75%        6.000000
# max       17.000000
# Name: Pregnancies, dtype: float64
# Central values of Pregnancies
# ----------------------------------------------------------------------------
#
# Minimum :  0
# Maximum :  17
# Mean value :  3.8450520833333335
# Median value :  3.0
# Standard deviation :  3.3695780626988623
# Null values :  False
# Null values :  0
# Quartile of Pregnancies
# ----------------------------------------------------------------------------
# 1st Quartile (Q1) is:  1.0
# 3st Quartile (Q3) is:  6.0
# Interquartile range (IQR) is  5.0
#
# Outlier detection from Interquartile range (IQR) Pregnancies
# ----------------------------------------------------------------------------
#
# Lower outliers range:  -6.5
#
# Upper outliers range:  13.5
# Number of outliers in upper :  4
# Number of outliers in lower :  0
# % of Outlier in upper:  1.0 %
# % of Outlier in lower:  0.0 %
#
# BoxPlot of Pregnancies
# ----------------------------------------------------------------------------
# distplot of Pregnancies
# ----------------------------------------------------------------------------
# Histogram of Pregnancies
# ----------------------------------------------------------------------------
# Histogram with mean, median and mode of Pregnancies
# ----------------------------------------------------------------------------
# Mean:  3.8450520833333335
# Median:  3.0
# Mode:  1
# Skewness of Pregnancies
# ----------------------------------------------------------------------------
# 0.9016739791518588
#
# Description of Glucose
# ----------------------------------------------------------------------------
# count    768.000000
# mean     120.894531
# std       31.972618
# min        0.000000
# 25%       99.000000
# 50%      117.000000
# 75%      140.250000
# max      199.000000
# Name: Glucose, dtype: float64
# Central values of Glucose
# ----------------------------------------------------------------------------
#
# Minimum :  0
# Maximum :  199
# Mean value :  120.89453125
# Median value :  117.0
# Standard deviation :  31.97261819513622
# Null values :  False
# Null values :  0
# Quartile of Glucose
# ----------------------------------------------------------------------------
# 1st Quartile (Q1) is:  99.0
# 3st Quartile (Q3) is:  140.25
# Interquartile range (IQR) is  41.25
#
# Outlier detection from Interquartile range (IQR) Glucose
# ----------------------------------------------------------------------------
#
# Lower outliers range:  37.125
#
# Upper outliers range:  202.125
# Number of outliers in upper :  0
# Number of outliers in lower :  5
# % of Outlier in upper:  0.0 %
# % of Outlier in lower:  1.0 %
#
# BoxPlot of Glucose
# ----------------------------------------------------------------------------
# distplot of Glucose
# ----------------------------------------------------------------------------
# Histogram of Glucose
# ----------------------------------------------------------------------------
# Histogram with mean, median and mode of Glucose
# ----------------------------------------------------------------------------
# Mean:  120.89453125
# Median:  117.0
# Mode:  99
# Skewness of Glucose
# ----------------------------------------------------------------------------
# 0.17375350179188992
#
# Description of BloodPressure
# ----------------------------------------------------------------------------
# count    768.000000
# mean      69.105469
# std       19.355807
# min        0.000000
# 25%       62.000000
# 50%       72.000000
# 75%       80.000000
# max      122.000000
# Name: BloodPressure, dtype: float64
# Central values of BloodPressure
# ----------------------------------------------------------------------------
#
# Minimum :  0
# Maximum :  122
# Mean value :  69.10546875
# Median value :  72.0
# Standard deviation :  19.355807170644777
# Null values :  False
# Null values :  0
# Quartile of BloodPressure
# ----------------------------------------------------------------------------
# 1st Quartile (Q1) is:  62.0
# 3st Quartile (Q3) is:  80.0
# Interquartile range (IQR) is  18.0
#
# Outlier detection from Interquartile range (IQR) BloodPressure
# ----------------------------------------------------------------------------
#
# Lower outliers range:  35.0
#
# Upper outliers range:  107.0
# Number of outliers in upper :  7
# Number of outliers in lower :  38
# % of Outlier in upper:  1.0 %
# % of Outlier in lower:  5.0 %
#
# BoxPlot of BloodPressure
# ----------------------------------------------------------------------------
# distplot of BloodPressure
# ----------------------------------------------------------------------------
# Histogram of BloodPressure
# ----------------------------------------------------------------------------
# Histogram with mean, median and mode of BloodPressure
# ----------------------------------------------------------------------------
# Mean:  69.10546875
# Median:  72.0
# Mode:  70
# Skewness of BloodPressure
# ----------------------------------------------------------------------------
# -1.8436079833551302
#
# Description of SkinThickness
# ----------------------------------------------------------------------------
# count    768.000000
# mean      20.536458
# std       15.952218
# min        0.000000
# 25%        0.000000
# 50%       23.000000
# 75%       32.000000
# max       99.000000
# Name: SkinThickness, dtype: float64
# Central values of SkinThickness
# ----------------------------------------------------------------------------
#
# Minimum :  0
# Maximum :  99
# Mean value :  20.536458333333332
# Median value :  23.0
# Standard deviation :  15.952217567727677
# Null values :  False
# Null values :  0
# Quartile of SkinThickness
# ----------------------------------------------------------------------------
# 1st Quartile (Q1) is:  0.0
# 3st Quartile (Q3) is:  32.0
# Interquartile range (IQR) is  32.0
#
# Outlier detection from Interquartile range (IQR) SkinThickness
# ----------------------------------------------------------------------------
#
# Lower outliers range:  -48.0
#
# Upper outliers range:  80.0
# Number of outliers in upper :  1
# Number of outliers in lower :  0
# % of Outlier in upper:  0.0 %
# % of Outlier in lower:  0.0 %
#
# BoxPlot of SkinThickness
# ----------------------------------------------------------------------------
# distplot of SkinThickness
# ----------------------------------------------------------------------------
# Histogram of SkinThickness
# ----------------------------------------------------------------------------
# Histogram with mean, median and mode of SkinThickness
# ----------------------------------------------------------------------------
# Mean:  20.536458333333332
# Median:  23.0
# Mode:  0
# Skewness of SkinThickness
# ----------------------------------------------------------------------------
# 0.10937249648187608
#
# Description of Insulin
# ----------------------------------------------------------------------------
# count    768.000000
# mean      79.799479
# std      115.244002
# min        0.000000
# 25%        0.000000
# 50%       30.500000
# 75%      127.250000
# max      846.000000
# Name: Insulin, dtype: float64
# Central values of Insulin
# ----------------------------------------------------------------------------
#
# Minimum :  0
# Maximum :  846
# Mean value :  79.79947916666667
# Median value :  30.5
# Standard deviation :  115.24400235133837
# Null values :  False
# Null values :  0
# Quartile of Insulin
# ----------------------------------------------------------------------------
# 1st Quartile (Q1) is:  0.0
# 3st Quartile (Q3) is:  127.25
# Interquartile range (IQR) is  127.25
#
# Outlier detection from Interquartile range (IQR) Insulin
# ----------------------------------------------------------------------------
#
# Lower outliers range:  -190.875
#
# Upper outliers range:  318.125
# Number of outliers in upper :  34
# Number of outliers in lower :  0
# % of Outlier in upper:  4.0 %
# % of Outlier in lower:  0.0 %
#
# BoxPlot of Insulin
# ----------------------------------------------------------------------------
# distplot of Insulin
# ----------------------------------------------------------------------------
# Histogram of Insulin
# ----------------------------------------------------------------------------
# Histogram with mean, median and mode of Insulin
# ----------------------------------------------------------------------------
# Mean:  79.79947916666667
# Median:  30.5
# Mode:  0
# Skewness of Insulin
# ----------------------------------------------------------------------------
# 2.272250858431574
#
# Description of BMI
# ----------------------------------------------------------------------------
# count    768.000000
# mean      31.992578
# std        7.884160
# min        0.000000
# 25%       27.300000
# 50%       32.000000
# 75%       36.600000
# max       67.100000
# Name: BMI, dtype: float64
# Central values of BMI
# ----------------------------------------------------------------------------
#
# Minimum :  0.0
# Maximum :  67.1
# Mean value :  31.992578124999977
# Median value :  32.0
# Standard deviation :  7.8841603203754405
# Null values :  False
# Null values :  0
# Quartile of BMI
# ----------------------------------------------------------------------------
# 1st Quartile (Q1) is:  27.3
# 3st Quartile (Q3) is:  36.6
# Interquartile range (IQR) is  9.3
#
# Outlier detection from Interquartile range (IQR) BMI
# ----------------------------------------------------------------------------
#
# Lower outliers range:  13.35
#
# Upper outliers range:  50.550000000000004
# Number of outliers in upper :  8
# Number of outliers in lower :  11
# % of Outlier in upper:  1.0 %
# % of Outlier in lower:  1.0 %
#
# BoxPlot of BMI
# ----------------------------------------------------------------------------
# distplot of BMI
# ----------------------------------------------------------------------------
# Histogram of BMI
# ----------------------------------------------------------------------------
# Histogram with mean, median and mode of BMI
# ----------------------------------------------------------------------------
# Mean:  31.992578124999977
# Median:  32.0
# Mode:  32.0
# Skewness of BMI
# ----------------------------------------------------------------------------
# -0.42898158845356543
#
# Description of DiabetesPedigreeFunction
# ----------------------------------------------------------------------------
# count    768.000000
# mean       0.471876
# std        0.331329
# min        0.078000
# 25%        0.243750
# 50%        0.372500
# 75%        0.626250
# max        2.420000
# Name: DiabetesPedigreeFunction, dtype: float64
# Central values of DiabetesPedigreeFunction
# ----------------------------------------------------------------------------
#
# Minimum :  0.078
# Maximum :  2.42
# Mean value :  0.4718763020833327
# Median value :  0.3725
# Standard deviation :  0.33132859501277484
# Null values :  False
# Null values :  0
# Quartile of DiabetesPedigreeFunction
# ----------------------------------------------------------------------------
# 1st Quartile (Q1) is:  0.24375
# 3st Quartile (Q3) is:  0.62625
# Interquartile range (IQR) is  0.38249999999999995
#
# Outlier detection from Interquartile range (IQR) DiabetesPedigreeFunction
# ----------------------------------------------------------------------------
#
# Lower outliers range:  -0.32999999999999996
#
# Upper outliers range:  1.2
# Number of outliers in upper :  29
# Number of outliers in lower :  0
# % of Outlier in upper:  4.0 %
# % of Outlier in lower:  0.0 %
#
# BoxPlot of DiabetesPedigreeFunction
# ----------------------------------------------------------------------------
# distplot of DiabetesPedigreeFunction
# ----------------------------------------------------------------------------
# Histogram of DiabetesPedigreeFunction
# ----------------------------------------------------------------------------
# Histogram with mean, median and mode of DiabetesPedigreeFunction
# ----------------------------------------------------------------------------
# Mean:  0.4718763020833327
# Median:  0.3725
# Mode:  0.254
# Skewness of DiabetesPedigreeFunction
# ----------------------------------------------------------------------------
# 1.919911066307204
#
# Description of Age
# ----------------------------------------------------------------------------
# count    768.000000
# mean      33.240885
# std       11.760232
# min       21.000000
# 25%       24.000000
# 50%       29.000000
# 75%       41.000000
# max       81.000000
# Name: Age, dtype: float64
# Central values of Age
# ----------------------------------------------------------------------------
#
# Minimum :  21
# Maximum :  81
# Mean value :  33.240885416666664
# Median value :  29.0
# Standard deviation :  11.76023154067868
# Null values :  False
# Null values :  0
# Quartile of Age
# ----------------------------------------------------------------------------
# 1st Quartile (Q1) is:  24.0
# 3st Quartile (Q3) is:  41.0
# Interquartile range (IQR) is  17.0
#
# Outlier detection from Interquartile range (IQR) Age
# ----------------------------------------------------------------------------
#
# Lower outliers range:  -1.5
#
# Upper outliers range:  66.5
# Number of outliers in upper :  9
# Number of outliers in lower :  0
# % of Outlier in upper:  1.0 %
# % of Outlier in lower:  0.0 %
#
# BoxPlot of Age
# ----------------------------------------------------------------------------
# distplot of Age
# ----------------------------------------------------------------------------
# Histogram of Age
# ----------------------------------------------------------------------------
# Histogram with mean, median and mode of Age
# ----------------------------------------------------------------------------
# Mean:  33.240885416666664
# Median:  29.0
# Mode:  22
# Skewness of Age
# ----------------------------------------------------------------------------
# 1.1295967011444805
#
# Description of Outcome
# ----------------------------------------------------------------------------
# count    768.000000
# mean       0.348958
# std        0.476951
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Outcome, dtype: float64
# Central values of Outcome
# ----------------------------------------------------------------------------
#
# Minimum :  0
# Maximum :  1
# Mean value :  0.3489583333333333
# Median value :  0.0
# Standard deviation :  0.4769513772427971
# Null values :  False
# Null values :  0
# Quartile of Outcome
# ----------------------------------------------------------------------------
# 1st Quartile (Q1) is:  0.0
# 3st Quartile (Q3) is:  1.0
# Interquartile range (IQR) is  1.0
#
# Outlier detection from Interquartile range (IQR) Outcome
# ----------------------------------------------------------------------------
#
# Lower outliers range:  -1.5
#
# Upper outliers range:  2.5
# Number of outliers in upper :  0
# Number of outliers in lower :  0
# % of Outlier in upper:  0.0 %
# % of Outlier in lower:  0.0 %
#
# BoxPlot of Outcome
# ----------------------------------------------------------------------------
# distplot of Outcome
# ----------------------------------------------------------------------------
# Histogram of Outcome
# ----------------------------------------------------------------------------
# Histogram with mean, median and mode of Outcome
# ----------------------------------------------------------------------------
# Mean:  0.3489583333333333
# Median:  0.0
# Mode:  0
# Skewness of Outcome
# ----------------------------------------------------------------------------
# 0.635016643444986

# %%
sns.pairplot(data,diag_kind='kde',kind='reg')

# %%
#correlation matrix
data.corr().T
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# Glucose                   0.331357  0.221071                  0.137337
# BloodPressure             0.088933  0.281805                  0.041265
# SkinThickness             0.436783  0.392573                  0.183928
# Insulin                   1.000000  0.197859                  0.185071
# BMI                       0.197859  1.000000                  0.140647
# DiabetesPedigreeFunction  0.185071  0.140647                  1.000000
# Age                      -0.042163  0.036242                  0.033561
# Outcome                   0.130548  0.292695                  0.173844
#
#                                Age   Outcome
# Pregnancies               0.544341  0.221898
# Glucose                   0.263514  0.466581
# BloodPressure             0.239528  0.065068
# SkinThickness            -0.113970  0.074752
# Insulin                  -0.042163  0.130548
# BMI                       0.036242  0.292695
# DiabetesPedigreeFunction  0.033561  0.173844
# Age                       1.000000  0.238356
# Outcome                   0.238356  1.000000

# %%
corr = df_num.corr(method='pearson')
mask = np.triu(np.ones_like(corr, dtype=np.bool)) 
fig = plt.subplots(figsize=(25, 15))
sns.heatmap(df_num.corr(), annot=True,fmt='.2f',mask=mask)
plt.show()

# %%
# Let us see the significant correlation either negative or positive among independent attributes..
c = data.corr().abs() # Since there may be positive as well as -ve correlation
s = c.unstack() # 
so = s.sort_values(ascending=False) # Sorting according to the correlation
so=so[(so<1) & (so>0.3)].drop_duplicates().to_frame() # Due to symmetry.. dropping duplicate entries.
so.columns = ['correlation']
so
# Out:
#                        correlation
# Pregnancies   Age         0.544341
# Outcome       Glucose     0.466581
# SkinThickness Insulin     0.436783
#               BMI         0.392573
# Glucose       Insulin     0.331357

# %%
model = GaussianNB()
cv_scores = cross_val_score(model, X, Y, cv=5)
    
print(model, ' mean accuracy: ', round(cv_scores.mean()*100, 3), '% std: ', round(cv_scores.var()*100, 3),'%')
# Out:
# GaussianNB()  mean accuracy:  75.134 % std:  0.035 %

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=0)

# %%
# Creating dataframe with 0 values in any cell
data1 = data.copy()
data1 = data1.drop(columns=['Outcome'],axis=1)
data1 = data1[(data1 == 0).any(axis=1)]
data1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# ..           ...      ...            ...            ...      ...   ...
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 764            2      122             70             27        0  36.8
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 4                       2.288   33
# 5                       0.201   30
# ..                        ...  ...
# 761                     0.403   43
# 762                     0.142   33
# 764                     0.340   27
# 766                     0.349   47
# 767                     0.315   23
#
# [432 rows x 8 columns]

# %%
#Conditional Formatting in pandas - Colouring cells having 0 (zero) values

data1.style.applymap(lambda x: 'background-color : red' if x==0 else '')
# Out:
# <style  type="text/css" >
# #T_f898a81e_5fb5_11eb_8a4f_0242ac130202row0_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row1_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row2_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row2_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row3_col0,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row4_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row4_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row5_col2,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row5_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row5_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row6_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row6_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row6_col5,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row7_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row7_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row8_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row8_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row9_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row9_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row10_col2,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row10_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row10_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row11_col0,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row12_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row12_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row13_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row13_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row14_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row14_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row15_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row16_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row16_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row17_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row17_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row18_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row19_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row19_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row20_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row21_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row21_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row22_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row23_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row24_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row24_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row25_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row26_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row26_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row27_col0,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row27_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row28_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row28_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row29_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row30_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row31_col2,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row31_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row31_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row31_col5,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row32_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row33_col0,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row34_col0,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row34_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row34_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row35_col0,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row36_col2,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row36_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row36_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row36_col5,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row37_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row37_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row38_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row38_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row39_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row39_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row40_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row41_col0,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row41_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row42_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row42_col4,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row43_col3,#T_f898a81e_5fb5_11eb_8a4f_0242ac130202row43_col4,#T_f898a81e_5fb5_11 ...

# %% [markdown]
# ## Imputing 0 (zero) values with mean

# %%
from sklearn.impute import SimpleImputer
rep_0 = SimpleImputer(missing_values=0, strategy="mean")
cols = X_train.columns
X_train = pd.DataFrame(rep_0.fit_transform(X_train))
X_test = pd.DataFrame(rep_0.fit_transform(X_test))

X_train.columns = cols
X_test.columns = cols

X_train.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness    Insulin   BMI  \
# 0     4.539474    151.0           90.0      46.000000  159.97193  42.1
# 1     1.000000     83.0           68.0      29.411458  159.97193  18.2
# 2     2.000000    122.0           70.0      27.000000  159.97193  36.8
# 3     4.000000    146.0           78.0      29.411458  159.97193  38.5
# 4     4.539474    123.0           72.0      29.411458  159.97193  36.3
#
#    DiabetesPedigreeFunction   Age
# 0                     0.371  21.0
# 1                     0.624  27.0
# 2                     0.340  27.0
# 3                     0.520  67.0
# 4                     0.258  52.0

# %%
y_pred = model.fit(X_train, y_train).predict(X_test)
print("Number of mislabeled points out of a total %d points : %d" % (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# Number of mislabeled points out of a total 231 points : 56

# %% [markdown]
# ## Accuracy

# %%
predict_train = model.fit(X_train, y_train).predict(X_train)

# Accuray Score on train dataset
accuracy_train = accuracy_score(y_train,predict_train)
print('accuracy_score on train dataset : ', accuracy_train)


# predict the target on the test dataset
predict_test = model.predict(X_test)

# Accuracy Score on test dataset
accuracy_test = accuracy_score(y_test,predict_test)
print('accuracy_score on test dataset : ', accuracy_test)
# Out:
# accuracy_score on train dataset :  0.7597765363128491
# accuracy_score on test dataset :  0.7575757575757576

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn import metrics
f,a =  plt.subplots(1,2,sharex=True,sharey=True,squeeze=False)

#Plotting confusion matrix for the different models for the Training Data

plot_0 = sns.heatmap((metrics.confusion_matrix(y_train,predict_train)),annot=True,fmt='.5g',cmap="YlGn",ax=a[0][0]);
a[0][0].set_title('Training Data')

plot_1 = sns.heatmap((metrics.confusion_matrix(y_test,predict_test)),annot=True,fmt='.5g',cmap="YlGn",ax=a[0][1]);
a[0][1].set_title('Test Data');

# %% [markdown]
# ## Classification Report

# %%
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix,plot_confusion_matrix
print(classification_report(y_train,predict_train))
print(classification_report(y_test,predict_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.83      0.81       343
#            1       0.68      0.64      0.66       194
#
#     accuracy                           0.76       537
#    macro avg       0.74      0.73      0.74       537
# weighted avg       0.76      0.76      0.76       537
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83       157
#            1       0.65      0.53      0.58        74
#
#     accuracy                           0.76       231
#    macro avg       0.72      0.70      0.71       231
# weighted avg       0.75      0.76      0.75       231

# %% [markdown]
# ## Hyperparameter Tuning to improve Accuracy
#
# Var_smoothing (Variance smoothing) parameter specifies the portion of the largest variance of all features to be added to variances for stability of calculation.
#
# Gaussian Naive Bayes assumes that features follows normal distribution which is most unlikely in real world.So solve this problem we can perform "power transformation" on each feature to make it more or less normally distributed. By default, PowerTransformer results in features that have a 0 mean and 1 standard deviation.

# %%
np.logspace(0,-9, num=10)
# Out:
# array([1.e+00, 1.e-01, 1.e-02, 1.e-03, 1.e-04, 1.e-05, 1.e-06, 1.e-07,
#        1.e-08, 1.e-09])

# %%
from sklearn.model_selection import RepeatedStratifiedKFold

cv_method = RepeatedStratifiedKFold(n_splits=5, 
                                    n_repeats=3, 
                                    random_state=999)

# %%
from sklearn.preprocessing import PowerTransformer
params_NB = {'var_smoothing': np.logspace(0,-9, num=100)}

gs_NB = GridSearchCV(estimator=model, 
                     param_grid=params_NB, 
                     cv=cv_method,
                     verbose=1, 
                     scoring='accuracy')

Data_transformed = PowerTransformer().fit_transform(X_test)

gs_NB.fit(Data_transformed, y_test);
# Out:
# Fitting 15 folds for each of 100 candidates, totalling 1500 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1500 out of 1500 | elapsed:    2.8s finished

# %%
gs_NB.best_params_
# Out:
# {'var_smoothing': 0.0533669923120631}

# %%
gs_NB.best_score_
# Out:
# 0.7775208140610546

# %%
results_NB = pd.DataFrame(gs_NB.cv_results_['params'])
results_NB['test_score'] = gs_NB.cv_results_['mean_test_score']

# %%
plt.plot(results_NB['var_smoothing'], results_NB['test_score'], marker = '.')    
plt.xlabel('Var. Smoothing')
plt.ylabel("Mean CV Score")
plt.title("NB Performance Comparison")
plt.show()

# %%
# predict the target on the test dataset
predict_test = gs_NB.predict(Data_transformed)

# Accuracy Score on test dataset
accuracy_test = accuracy_score(y_test,predict_test)
print('accuracy_score on test dataset : ', accuracy_test)
# Out:
# accuracy_score on test dataset :  0.7922077922077922

# %%
sns.heatmap((metrics.confusion_matrix(y_test,predict_test)),annot=True,fmt='.5g',cmap="YlGn").set_title('Test Data');
