# %% [markdown]
# # Naive Bayes

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
import statistics as stat

# %% [markdown]
# ## Question 1
#
# * Load the Iris dataset.
# * Take a quick look at the data types.
# * Plot the pairwise correlations and histograms.

# %%
data = pd.read_csv('iris.csv')
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.837584     3.057718      3.750336     1.193960
# std        0.827849     0.432651      1.767409     0.763547
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.300000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.catplot(data=data,kind='box' )

# %% [markdown]
# ### Removing outliners for sepal width

# %%
iqr = data['sepal_width'].quantile(0.75) - data['sepal_width'].quantile(0.25) 
print('iqr = ',iqr)
up = data['sepal_width'].quantile(0.75) + 1.5 * iqr
down = data['sepal_width'].quantile(0.25) - 1.5 * iqr
print('up = {} , down = {}'.format(up,down))
sepalw = data['sepal_width']

outlier = []
for i in sepalw:
    if i > up:
        print('outliner up ',i)
        outlier.append(i)

for i in sepalw:
    if i < down:
        print('outliner down ',i)
        outlier.append(i)
# Out:
# iqr =  0.5
# up = 4.05 , down = 2.05
# outliner up  4.4
# outliner up  4.1
# outliner up  4.2
# outliner down  2.0

# %%
data.sepal_width = data.sepal_width.replace(outlier,data.sepal_width.mean())

# %%
sns.catplot(data=data,kind='box' )

# %%
sns.pairplot(data,hue='species')

# %%
data.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
data.isnull().sum()
# Out:
# sepal_length    1
# sepal_width     1
# petal_length    1
# petal_width     1
# species         0
# dtype: int64

# %%
X = data.iloc[:,:4]
y = data.iloc[:,-1]
# Out:
# 0    setosa
# 1    setosa
# 2    setosa
# 3    setosa
# 4    setosa
# Name: species, dtype: object

# %%
## Encoding categorical value
from sklearn.preprocessing import LabelEncoder

label = LabelEncoder()
y = label.fit_transform(y)

# %%
## Imputing Missing Value
from sklearn.impute import SimpleImputer

impute = SimpleImputer(strategy='most_frequent')
X = impute.fit_transform(X)

# %%
## Transforming
from sklearn.preprocessing import MinMaxScaler

scale = MinMaxScaler()
X = scale.fit_transform(X)

# %% [markdown]
# ## Question 2
#
# Let's now fit a Naive Bayes classifier to this data in order to predict "species".
#
# * Pick the appropriate type of Naive Bayes given the nature of your dataset (data types of columns). Recall, choices are
#     * GaussianNB
#     * MultinomialNB
#     * BernoulliNB
# * Use cross validation to see how well your choice works.

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# %%
gnb = GaussianNB()
y_pred = gnb.fit(X_train, y_train).predict(X_test)

# %%
#gnb.score(y_pred,y_test)
#y_pred
accuracy_score(y_test,y_pred)
# Out:
# 0.9777777777777777

# %% [markdown]
# ### Multinomial

# %%
clf = MultinomialNB()
y_predm = clf.fit(X_train, y_train).predict(X_test)

# %%
print("Number of mislabeled points out of a total {} points :{}".format(X_test.shape[0], (y_test != y_predm).sum()))
# Out:
# Number of mislabeled points out of a total 45 points :18

# %%
clf.score(X,y)
# Out:
# 0.66

# %%
accuracy_score(y_test,y_predm)
# Out:
# 0.6

# %% [markdown]
# ### Binomial

# %%
clf2 = BernoulliNB()
y_predb = clf2.fit(X_train, y_train).predict(X_test)

# %%
print("Number of mislabeled points out of a total {} points :{}".format(X_test.shape[0], (y_test != y_predb).sum()))
# Out:
# Number of mislabeled points out of a total 45 points :33

# %%
clf2.score(X,y)
# Out:
# 0.37333333333333335

# %%
accuracy_score(y_test,y_predb)
# Out:
# 0.26666666666666666

# %% [markdown]
# ## Question 3:
#
# Now let's try all types of Naive Bayes and observe what happens
#
# * Compare the cross validation scores for Gaussian, Bernouilli and Multinomial Naive Bayes.
# * Why is BernoulliNB performing like it does?

# %%
a = cross_val_score(gnb, X, y, cv=5, scoring='accuracy')
print(a)
print('mean = ',stat.mean(a))
# Out:
# [0.86666667 0.96666667 0.93333333 0.9        0.96666667]
# mean =  0.9266666666666666

# %%
a = cross_val_score(clf, X, y, cv=5, scoring='accuracy' )
print(a)
print('mean = ',stat.mean(a))
# Out:
# [0.76666667 0.76666667 0.86666667 0.66666667 0.76666667]
# mean =  0.7666666666666667

# %%
a = cross_val_score(clf2, X, y, cv=5, scoring='accuracy' )
print(a)
print('mean = ',stat.mean(a))
# Out:
# [0.36666667 0.4        0.33333333 0.43333333 0.33333333]
# mean =  0.37333333333333335

# %% [markdown]
# ## Question 4:
#
# Let's see what happens when we take away the predictive features.
#
# * Check the pairplot histograms (diagonal) you produced above and identify the two most predictive features visually.
# * Remove the features which are very predictive, and re-do the comparison above. That is, get the cross validation scores for all types of Naive Bayes.

# %%
sns.pairplot(data2,hue = 'species')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 sns.pairplot(data2,hue = 'species')
#
# NameError: name 'data2' is not defined

# %%
data3 = data2
data3 = data3.drop(['sepal_length','sepal_width'],axis=1)
sns.pairplot(data3, hue='species' )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [49], in <cell line: 1>()
# ----> 1 data3 = data2
#       2 data3 = data3.drop(['sepal_length','sepal_width'],axis=1)
#       3 sns.pairplot(data3, hue='species' )
#
# NameError: name 'data2' is not defined

# %%
data2 = data2.drop(['petal_length','petal_width'],axis=1)
sns.pairplot(data2, hue='species' )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [50], in <cell line: 1>()
# ----> 1 data2 = data2.drop(['petal_length','petal_width'],axis=1)
#       2 sns.pairplot(data2, hue='species' )
#
# NameError: name 'data2' is not defined

# %% [markdown]
# ## Question 5
#
# This question explores how Naive Bayes algorithms can be affected when we push the underlying (naive) assumption too much. Recall that the naive assumption is that the features in the training set are *independent* from each other.
#
# * Create **0, 1, 3, 5, 10, 50, 100** copies of `sepal_length` and fit a `GaussianNB` for each one.
# * Keep track of the save the average `cross_val_score`.
# * Create a plot of the saved scores over the number of copies.

# %%
data2 = data
final = []

#for i in range (10):
#     data2['sepal_length'+str(i)]=data2['sepal_length']
a  = [0,1,3,5,10,50,100]



for i in a:
    for j in range(i):
        data2['sepal_length'+str(j)]=data2['sepal_length']
    print(data2.columns,'\n\n')
    temp = cross_val_score(gnb, data2, y, cv=5, scoring='accuracy' )
    final.append(stat.mean(temp))
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [51], in <cell line: 10>()
#      12     data2['sepal_length'+str(j)]=data2['sepal_length']
#      13 print(data2.columns,'\n\n')
# ---> 14 temp = cross_val_score(gnb, data2, y, cv=5, scoring='accuracy' )
#      15 final.append(stat.mean(temp))
#
# File /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:515, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     512 # To ensure multimetric format is not supported
#     513 scorer = check_scoring(estimator, scoring=scoring)
# --> 515 cv_results = cross_validate(
#     516     estimator=estimator,
#     517     X=X,
#     518     y=y,
#     519     groups=groups,
#     520     scoring={"score": scorer},
#     521     cv=cv,
#     522     n_jobs=n_jobs,
#     523     verbose=verbose,
#     524     fit_params=fit_params,
#     525     pre_dispatch=pre_dispatch,
#     526     error_score=error_score,
#     527 )
#     528 return cv_results["test_score"]
#
# File /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:285, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     265 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
#     266 results = parallel(
#     267     delayed(_fit_and_score)(
#     268         clone(estimator),
#    (...)
#     282     for train, test in cv.split(X, y, groups)
#     283 )
# --> 285 _warn_or_raise_about_fit_failures(results, error_score)
#     287 # For callabe scoring, the return type is only know after calling. If the
#     288 # return type is a dictionary, the error scores can now be inserted with
#     289 # the correct key.
#     290 if callable(scoring):
#
# File /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:367, in _warn_or_raise_about_fit_failures(results, error_score)
#     360 if num_failed_fits == num_fits:
#     361     all_fits_failed_message = (
#     362         f"\nAll the {num_fits} fits failed.\n"
#     363         "It is is very likely that your model is misconfigured.\n"
#     364         "You can try to debug the error by setting error_score='raise'.\n\n"
#     365         f"Below are more details about the failures:\n{fit_errors_summary}"
#     366     )
# --> 367     raise ValueError(all_fits_failed_message)
#     369 else:
#     370     some_fits_failed_message = (
#     371         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     372         "The score on these train-test partitions for these parameters"
#    (...)
#     376         f"Below are more details about the failures:\n{fit_errors_summary}"
#     377     )
#
# ValueError:
# All the 5 fits failed.
# It is is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/naive_bayes.py", line 243, in fit
#     return self._partial_fit(
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/naive_bayes.py", line 400, in _partial_fit
#     X, y = self._validate_data(X, y, reset=first_call)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/base.py", line 596, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py", line 1070, in check_X_y
#     X = check_array(
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py", line 852, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/home/iamtechnicalnahid/.local/lib/python3.8/site-packages/pandas/core/generic.py", line 2072, in __array__
#     return np.asarray(self._values, dtype=dtype)
# ValueError: could not convert string to float: 'setosa'

# %%
print(final)
# Out:
# [0.9333333333333333, 0.9333333333333333, 0.9133333333333333, 0.86, 0.8466666666666667, 0.76, 0.76]

# %%
plt.plot(a,final)
plt.xlabel('No. of Independent variables')
plt.ylabel('Accuracy Score')
plt.title('Accuracy vs Independent variables')
# Out:
# Text(0.5, 1.0, 'Accuracy vs Independent variables')
