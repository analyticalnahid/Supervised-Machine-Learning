# %%
import numpy as np
import pandas as pd
import seaborn as snp
from sklearn.ensemble import VotingClassifier

# %%
df = pd.read_csv('iris.csv')

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['variety'] = encoder.fit_transform(df['variety'])

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width  variety
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
snp.pairplot(df,hue='variety')

# %%
new_df = df[df['variety'] != 0][['sepal.length','sepal.width','variety']]

# %%
new_df.head()
# Out:
#     sepal.length  sepal.width  variety
# 50           7.0          3.2        1
# 51           6.4          3.2        1
# 52           6.9          3.1        1
# 53           5.5          2.3        1
# 54           6.5          2.8        1

# %%
X = new_df.iloc[:,0:2]
y = new_df.iloc[:,-1]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score

# %%
clf1 = LogisticRegression()
clf2 = RandomForestClassifier()
clf3 = KNeighborsClassifier()

# %%
estimators = [('lr',clf1),('rf',clf2),('knn',clf3)]

# %%
for estimator in estimators:
    x = cross_val_score(estimator[1],X,y,cv=10,scoring='accuracy')
    print(estimator[0],np.round(np.mean(x),2))
# Out:
# lr 0.75
# rf 0.61
# knn 0.61

# %% [markdown]
# ## Hard Voting

# %%
vth = VotingClassifier(estimators=estimators,voting='hard')
x = cross_val_score(estimator[1],X,y,cv=10,scoring='accuracy')
print(np.round(np.mean(x),2))
# Out:
# 0.61

# %% [markdown]
# ## Soft Voting

# %%
vts = VotingClassifier(estimators=estimators,voting='soft')
x = cross_val_score(vts,X,y,cv=10,scoring='accuracy')
print(np.round(np.mean(x),2))
# Out:
# 0.65

# %% [markdown]
# ## Weighted Voting

# %%
for i in range(1,4):
    for j in range(1,4):
        for k in range(1,4):
            vts = VotingClassifier(estimators=estimators,voting='soft', weights=[i,j,k])
            x = cross_val_score(vts,X,y,cv=10,scoring='accuracy')
            print("for i={},j={},k={}".format(i,j,k),np.round(np.mean(x),2))
# Out:
# for i=1,j=1,k=1 0.64
# for i=1,j=1,k=2 0.63
# for i=1,j=1,k=3 0.64
# for i=1,j=2,k=1 0.66
# for i=1,j=2,k=2 0.63
# for i=1,j=2,k=3 0.64
# for i=1,j=3,k=1 0.64
# for i=1,j=3,k=2 0.66
# for i=1,j=3,k=3 0.65
# for i=2,j=1,k=1 0.7
# for i=2,j=1,k=2 0.68
# for i=2,j=1,k=3 0.65
# for i=2,j=2,k=1 0.68
# for i=2,j=2,k=2 0.65
# for i=2,j=2,k=3 0.63
# for i=2,j=3,k=1 0.65
# for i=2,j=3,k=2 0.64
# for i=2,j=3,k=3 0.66
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
#       3 for k in range(1,4):
#       4     vts = VotingClassifier(estimators=estimators,voting='soft', weights=[i,j,k])
# ----> 5     x = cross_val_score(vts,X,y,cv=10,scoring='accuracy')
#       6     print("for i={},j={},k={}".format(i,j,k),np.round(np.mean(x),2))
#
# ...

# %% [markdown]
# ## Classifier For Same Algo

# %%
from sklearn.datasets import make_classification
X,y = make_classification(n_samples=1000, n_features=20, n_informative=15, n_redundant=5, random_state= 2)

svm1 = SVC(probability=True, kernel='poly', degree=1)
svm2 = SVC(probability=True, kernel='poly', degree=2)
svm3 = SVC(probability=True, kernel='poly', degree=3)
svm4 = SVC(probability=True, kernel='poly', degree=4)
svm5 = SVC(probability=True, kernel='poly', degree=5)

estimators = [('svm1',svm1), ('svm2',svm2), ('svm3', svm3), ('svm4', svm4), ('svm5',svm5)]

for estimator in estimators:
    x = cross_val_score(estimator[1],X,y,cv=10,scoring='accuracy')
    print(estimator[0],np.round(np.mean(x),2))
# Out:
# svm1 0.85
# svm2 0.85
# svm3 0.89
# svm4 0.81
# svm5 0.86

# %%
vts = VotingClassifier(estimators=estimators,voting='soft')
x = cross_val_score(vts,X,y,cv=10,scoring='accuracy')
print(np.round(np.mean(x),2))
# Out:
# 0.93
